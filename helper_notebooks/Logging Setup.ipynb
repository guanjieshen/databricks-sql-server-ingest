# %%
# %sql
CREATE OR REPLACE MATERIALIZED VIEW gshen_sqlserver_ct.default.gateway_logs
SCHEDULE EVERY 1 HOUR
AS
SELECT * FROM read_files('/Volumes/gshen_sqlserver_ct/default/ct/logs/', format => 'parquet');

# %%
# %sql
SELECT * FROM gshen_sqlserver_ct.default.gateway_logs
